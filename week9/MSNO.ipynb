# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\dell\Desktop\Python\week9\weatherAUS.csv')
df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %%
df.columns = df.columns.str.lower()

# %%
df.columns
# Out:
# Index(['date', 'location', 'mintemp', 'maxtemp', 'rainfall', 'evaporation',
#        'sunshine', 'windgustdir', 'windgustspeed', 'winddir9am', 'winddir3pm',
#        'windspeed9am', 'windspeed3pm', 'humidity9am', 'humidity3pm',
#        'pressure9am', 'pressure3pm', 'cloud9am', 'cloud3pm', 'temp9am',
#        'temp3pm', 'raintoday', 'raintomorrow'],
#       dtype='object')

# %% [markdown]
# ## Missing values

# %%
df.isnull().sum()
# Out:
# date                 0
# location             0
# mintemp           1485
# maxtemp           1261
# rainfall          3261
# evaporation      62790
# sunshine         69835
# windgustdir      10326
# windgustspeed    10263
# winddir9am       10566
# winddir3pm        4228
# windspeed9am      1767
# windspeed3pm      3062
# humidity9am       2654
# humidity3pm       4507
# pressure9am      15065
# pressure3pm      15028
# cloud9am         55888
# cloud3pm         59358
# temp9am           1767
# temp3pm           3609
# raintoday         3261
# raintomorrow      3267
# dtype: int64

# %%
round(df.isnull().sum() / len(df) *100, 2)
# Out:
# date              0.00
# location          0.00
# mintemp           1.02
# maxtemp           0.87
# rainfall          2.24
# evaporation      43.17
# sunshine         48.01
# windgustdir       7.10
# windgustspeed     7.06
# winddir9am        7.26
# winddir3pm        2.91
# windspeed9am      1.21
# windspeed3pm      2.11
# humidity9am       1.82
# humidity3pm       3.10
# pressure9am      10.36
# pressure3pm      10.33
# cloud9am         38.42
# cloud3pm         40.81
# temp9am           1.21
# temp3pm           2.48
# raintoday         2.24
# raintomorrow      2.25
# dtype: float64

# %%
# !pip install missingno

# %%
import missingno as msno

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %%
msno.bar(df)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Şəkilin ölçüsünü təyin etmək üçün plt.figure() istifadə edin
plt.figure(figsize=(10, 6))  # Burada 10 genişlik, 6 isə hündürlükdür

# Heatmap yaratmaq
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='Dark2_r')

# Şəkili göstərmək
plt.show()
