# %% [markdown]
# ### Manual Narimonov tapmaq ve bir sehifeni daramaq

# %%
import time

from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service

from selenium.webdriver.common.action_chains import ActionChains


chrome_options = webdriver.ChromeOptions()
service = Service(executable_path=ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=chrome_options)
actions = ActionChains(driver)


driver.get("https://bina.az/baki/neriman-nerimanov/alqi-satqi/menziller")

PRICE_LOCATOR = ("xpath", "//span[@class='price-val']")
LOCATION_LOCATOR = ("xpath", "//div[@class='location']")
OTAQ_LOCATOR = ("xpath", "//ul[@class='name']/li[1]")
SAHE_LOCATOR = ("xpath", "//ul[@class='name']/li[2]")
MERTEBE_LOCATOR = ("xpath", "//ul[@class='name']/li[3]")

PRICE_BUTTON = driver.find_elements(*PRICE_LOCATOR)
LOCATIO_BUTTON = driver.find_elements(*LOCATION_LOCATOR)
OTAQ_BUTTON = driver.find_elements(*OTAQ_LOCATOR)
SAHE_BUTTON = driver.find_elements(*SAHE_LOCATOR)
MERTEBE_BUTTON = driver.find_elements(*MERTEBE_LOCATOR)

price = []
location = []
otaq_sayi = []
sahe = []
mertebe = []
print(len(PRICE_BUTTON))
for i, j, z, t, m in zip(PRICE_BUTTON, LOCATIO_BUTTON, OTAQ_BUTTON, SAHE_BUTTON, MERTEBE_BUTTON):
    price.append(i.text)
    location.append(j.text)
    otaq_sayi.append(z.text)
    sahe.append(t.text)
    mertebe.append(m.text)
    
import pandas as pd    
pd.DataFrame({'Location': location, "Room": otaq_sayi, "Area": sahe, "Floor": mertebe, "Price": price})
# Out:
# 28
#                 Location      Room      Area          Floor    Price
# 0             Gənclik m.  2 otaqlı     53 m²   8/16 mərtəbə  183 000
# 1   Nəriman Nərimanov m.  2 otaqlı     83 m²   7/14 mərtəbə  265 000
# 2   Nəriman Nərimanov m.  4 otaqlı  122.3 m²   9/14 mərtəbə  305 850
# 3   Nəriman Nərimanov m.  2 otaqlı     44 m²    3/5 mərtəbə   97 800
# 4   Nəriman Nərimanov m.  3 otaqlı     90 m²  13/17 mərtəbə  250 000
# 5   Nəriman Nərimanov m.  2 otaqlı     65 m²   7/14 mərtəbə  188 000
# 6   Nəriman Nərimanov m.  3 otaqlı    130 m²   9/20 mərtəbə  255 000
# 7   Nəriman Nərimanov m.  3 otaqlı  155.5 m²   5/16 mərtəbə  350 000
# 8   Nəriman Nərimanov m.  4 otaqlı    170 m²  16/17 mərtəbə  560 000
# 9   Nəriman Nərimanov m.  2 otaqlı     50 m²    5/5 mərtəbə  140 000
# 10  Nəriman Nərimanov m.  2 otaqlı     55 m²    5/5 mərtəbə  139 000
# 11  Nəriman Nərimanov m.  2 otaqlı     66 m²  15/16 mərtəbə  175 000
# 12  Nəriman Nərimanov m.  2 otaqlı     93 m²  10/16 mərtəbə  240 000
# 13  Nəriman Nərimanov m.  4 otaqlı  122.3 m²   9/14 mərtəbə  305 850
# 14  Nəriman Nərimanov m.  2 otaqlı     52 m²   3/14 mərtəbə  145 000
# 15  Nəriman Nərimanov m.  2 otaqlı     60 m²   7/16 mərtəbə  156 000
# 16  Nəriman Nərimanov m.  2 otaqlı     53 m²   5/18 mərtəbə  137 000
# 17  Nəriman Nərimanov m.  3 otaqlı    100 m²  12/12 mərtəbə  300 000
# 18  Nəriman Nərimanov m.  3 otaqlı     70 m²    2/9 mərtəbə  170 000
# 19  Nəriman Nərimanov m.  3 otaqlı    140 m²   6/16 mərtəbə  490 000
# 20  Nəriman Nərimanov m.  2 otaqlı     95 m²  11/17 mərtəbə  269 000
# 21  Nəriman Nərimanov m.  4 otaqlı    265 m²   6/20 mərtəbə  680 000
# 22  Nəriman Nərimanov m.  2 otaqlı    105 m²   7/17 mərtəbə  265 000
# 23  Nəriman Nərimanov m.  3 otaqlı    117 m²  12/17 mərtəbə  242 000
# 24  Nəriman Nərimanov m.  2 otaqlı     70 m²   3/17 mərtəbə  195 000
# 25  Nəriman Nərimanov m.  2 otaqlı     47 m²    9/9 mərtəbə  138 000
# 26  Nəriman Nərimanov m.  4 otaqlı    136 m²   6/20 mərtəbə  295 000
# 27  Nəriman Nərimanov m.  3 otaqlı    150 m²  10/16 mərtəbə  395 000

# %% [markdown]
# ### Manual Narimonov tapmaq ve 4 sehifeni daramaq

# %%
import time

from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service

from selenium.webdriver.common.action_chains import ActionChains


chrome_options = webdriver.ChromeOptions()
service = Service(executable_path=ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=chrome_options)
actions = ActionChains(driver)

driver.get("https://bina.az/baki/neriman-nerimanov/alqi-satqi/menziller")

price = []
location = []
otaq_sayi = []
sahe = []
mertebe = []

n = 0
while n<4:
    time.sleep(2)
    PRICE_LOCATOR = ("xpath", "//span[@class='price-val']")
    LOCATION_LOCATOR = ("xpath", "//div[@class='location']")
    OTAQ_LOCATOR = ("xpath", "//ul[@class='name']/li[1]")
    SAHE_LOCATOR = ("xpath", "//ul[@class='name']/li[2]")
    MERTEBE_LOCATOR = ("xpath", "//ul[@class='name']/li[3]")

    PRICE_BUTTON = driver.find_elements(*PRICE_LOCATOR)
    LOCATIO_BUTTON = driver.find_elements(*LOCATION_LOCATOR)
    OTAQ_BUTTON = driver.find_elements(*OTAQ_LOCATOR)
    SAHE_BUTTON = driver.find_elements(*SAHE_LOCATOR)
    MERTEBE_BUTTON = driver.find_elements(*MERTEBE_LOCATOR)

    
    print(len(PRICE_BUTTON))
    for i, j, z, t, m in zip(PRICE_BUTTON, LOCATIO_BUTTON, OTAQ_BUTTON, SAHE_BUTTON, MERTEBE_BUTTON):
        price.append(i.text)
        location.append(j.text)
        otaq_sayi.append(z.text)
        sahe.append(t.text)
        mertebe.append(m.text)
        
    time.sleep(1)  
    
    try:
        NOVBETI_BUTTON = driver.find_element(By.XPATH, "//span[@class='next']")
        NOVBETI_BUTTON.click()
        

    except StaleElementReferenceException:
        print("Element köhnəlmişdir, yenidən tapmağa çalışıram...")
        time.sleep(3)  # Bir az gözləmək
    n+=1   

import pandas as pd
pd.DataFrame({'Location': location, "Room": otaq_sayi, "Area": sahe, "Floor": mertebe, "Price": price})
# Out:
# 28
# 28
# 28
# 28
#                  Location      Room    Area          Floor      Price
# 0    Nəriman Nərimanov m.  2 otaqlı   46 m²    3/4 mərtəbə    160 000
# 1    Nəriman Nərimanov m.  5 otaqlı  400 m²  10/16 mərtəbə  1 450 000
# 2              Gənclik m.  3 otaqlı  140 m²   6/17 mərtəbə    490 000
# 3    Nəriman Nərimanov m.  2 otaqlı   54 m²   9/17 mərtəbə    187 000
# 4    Nəriman Nərimanov m.  3 otaqlı   90 m²  13/17 mərtəbə    250 000
# ..                    ...       ...     ...            ...        ...
# 107  Nəriman Nərimanov m.  2 otaqlı   65 m²  10/17 mərtəbə    185 000
# 108  Nəriman Nərimanov m.  4 otaqlı  175 m²   3/14 mərtəbə    850 000
# 109  Nəriman Nərimanov m.  3 otaqlı   75 m²    2/5 mərtəbə    215 000
# 110  Nəriman Nərimanov m.  3 otaqlı  135 m²   7/17 mərtəbə    280 000
# 111  Nəriman Nərimanov m.  1 otaqlı   42 m²    5/9 mərtəbə    128 000
#
# [112 rows x 5 columns]

# %% [markdown]
# ### Auto click ile Narimanov tapmaq ve 4 sehife daramaq

# %%
import time

from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service

from selenium.webdriver.common.action_chains import ActionChains


chrome_options = webdriver.ChromeOptions()
service = Service(executable_path=ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=chrome_options)
actions = ActionChains(driver)

driver.get("https://bina.az/agsu/alqi-satqi/menziller")

FILTER_SELECT_LOCATOR = ("xpath", "(//span[@class='button'])[4]")
BAKI_SELECT_LOCATOR = ("xpath", "//span[text()='Bakı']")
ETRAFLI_SLECET_LOCATOR =("xpath", "//div[@class='search-row__cell search-row__cell--filters']")
METRO_SELECT_LOCATOR = ("xpath", "//span[text()='Metrostansiyalar']")
NARIMANOV_SELECET_LOCATOR = ("xpath", "//span[text()='Nəriman Nərimanov']")
AXTARISA_ELAVE_ET_LOCATOR = ("xpath", "(//div[text()='Axtarışa əlavə et'])[3]")
ELANI_GOSTER_LOCATOR = ("xpath", "//button[@class='search-filters__submit js-search-filters-items-count']")


FILTER_SELECT_BUTTON = driver.find_element(*FILTER_SELECT_LOCATOR)
BAKI_SELECT_BUTTON = driver.find_element(*BAKI_SELECT_LOCATOR)
ETRAFLI_BUTTON = driver.find_element(*ETRAFLI_SLECET_LOCATOR)
METRO_SELECT_BUTTON = driver.find_element(*METRO_SELECT_LOCATOR)
NARIMANOV_SELECT_BUTTON = driver.find_element(*NARIMANOV_SELECET_LOCATOR)
AXTARISA_ELAVE_ET_BUTTON = driver.find_element(*AXTARISA_ELAVE_ET_LOCATOR)
ELANI_GOSTER_BUTTON = driver.find_element(*ELANI_GOSTER_LOCATOR)


FILTER_SELECT_BUTTON.click()
time.sleep(1)
BAKI_SELECT_BUTTON.click()
time.sleep(1)
ETRAFLI_BUTTON.click()
time.sleep(1)
METRO_SELECT_BUTTON.click()
time.sleep(1)
NARIMANOV_SELECT_BUTTON.click()
time.sleep(1)
AXTARISA_ELAVE_ET_BUTTON.click()
time.sleep(1)
ELANI_GOSTER_BUTTON.click()
time.sleep(3)

price = []
location = []
otaq_sayi = []
sahe = []
mertebe = []

n = 0
while n<4:
    time.sleep(2)
    PRICE_LOCATOR = ("xpath", "//span[@class='price-val']")
    LOCATION_LOCATOR = ("xpath", "//div[@class='location']")
    OTAQ_LOCATOR = ("xpath", "//ul[@class='name']/li[1]")
    SAHE_LOCATOR = ("xpath", "//ul[@class='name']/li[2]")
    MERTEBE_LOCATOR = ("xpath", "//ul[@class='name']/li[3]")

    PRICE_BUTTON = driver.find_elements(*PRICE_LOCATOR)
    LOCATIO_BUTTON = driver.find_elements(*LOCATION_LOCATOR)
    OTAQ_BUTTON = driver.find_elements(*OTAQ_LOCATOR)
    SAHE_BUTTON = driver.find_elements(*SAHE_LOCATOR)
    MERTEBE_BUTTON = driver.find_elements(*MERTEBE_LOCATOR)

    
    print(len(PRICE_BUTTON))
    for i, j, z, t, m in zip(PRICE_BUTTON, LOCATIO_BUTTON, OTAQ_BUTTON, SAHE_BUTTON, MERTEBE_BUTTON):
        price.append(i.text)
        location.append(j.text)
        otaq_sayi.append(z.text)
        sahe.append(t.text)
        mertebe.append(m.text)
        
    time.sleep(2)  
    
    try:
        NOVBETI_BUTTON = driver.find_element(By.XPATH, "//span[@class='next']")
        NOVBETI_BUTTON.click()
        

    except StaleElementReferenceException:
        print("Element köhnəlmişdir, yenidən tapmağa çalışıram...")
        time.sleep(2)  # Bir az gözləmək
    n+=1   

import pandas as pd
pd.DataFrame({'Location': location, "Room": otaq_sayi, "Area": sahe, "Floor": mertebe, "Price": price})
# Out:
# 28
# 28
# 28
# 28
#                  Location      Room    Area          Floor      Price
# 0    Nəriman Nərimanov m.  5 otaqlı  400 m²  10/16 mərtəbə  1 450 000
# 1    Nəriman Nərimanov m.  3 otaqlı  110 m²  14/14 mərtəbə    247 000
# 2    Nəriman Nərimanov m.  3 otaqlı  157 m²   9/15 mərtəbə    450 000
# 3    Nəriman Nərimanov m.  2 otaqlı   75 m²  12/17 mərtəbə    245 000
# 4    Nəriman Nərimanov m.  4 otaqlı  180 m²  12/15 mərtəbə    285 000
# ..                    ...       ...     ...            ...        ...
# 107            Gənclik m.  2 otaqlı   53 m²   8/16 mərtəbə    183 000
# 108  Nəriman Nərimanov m.  2 otaqlı   65 m²  10/17 mərtəbə    185 000
# 109  Nəriman Nərimanov m.  4 otaqlı  175 m²   3/14 mərtəbə    850 000
# 110  Nəriman Nərimanov m.  3 otaqlı   75 m²    2/5 mərtəbə    215 000
# 111  Nəriman Nərimanov m.  3 otaqlı  135 m²   7/17 mərtəbə    280 000
#
# [112 rows x 5 columns]

# %% [markdown]
# #### Move ile nerimanov tapmaq

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.action_chains import ActionChains
import time


options = Options()
driver = webdriver.Chrome(options=options)
actions = ActionChains(driver)


driver.get("https://bina.az/agsu/alqi-satqi/menziller")

FILTER_SELECT_LOCATOR = ("xpath", "(//span[@class='button'])[4]")
SELECT_BAKI_LOCATOR = ("xpath", "//span[text()='Bakı']")
ETRAFLI_SLECET_LOCATOR =("xpath", "//div[@class='search-row__cell search-row__cell--filters']")
METRO_SELECT_LOCATOR = ("xpath", "//span[text()='Metrostansiyalar']")
NARIMANOV_SELECET_LOCATOR = ("xpath", "//span[text()='Nəriman Nərimanov']")
AXTARISA_ELAVE_ET_LOCATOR = ("xpath", "(//div[text()='Axtarışa əlavə et'])[3]")
ELANI_GOSTER_LOCATOR = ("xpath", "//button[@class='search-filters__submit js-search-filters-items-count']")
# NOVBETI_LOCATOR = ("xpath", "//span[@class='next']")

FILTER_SELECT_BUTTON = driver.find_element(*FILTER_SELECT_LOCATOR)
SELECT_BAKI_BUTTON = driver.find_element(*SELECT_BAKI_LOCATOR)
ETRAFLI_BUTTON = driver.find_element(*ETRAFLI_SLECET_LOCATOR)
METRO_SELECT_BUTTON = driver.find_element(*METRO_SELECT_LOCATOR)
NARIMANOV_SELECT_BUTTON = driver.find_element(*NARIMANOV_SELECET_LOCATOR)
AXTARISA_ELAVE_ET_BUTTON = driver.find_element(*AXTARISA_ELAVE_ET_LOCATOR)
ELANI_GOSTER_BUTTON = driver.find_element(*ELANI_GOSTER_LOCATOR)
# NOVBETI_BUTTON = driver.find_element(*NOVBETI_LOCATOR)

FILTER_SELECT_BUTTON.click() 
actions.move_to_element(SELECT_BAKI_BUTTON).click().perform()

time.sleep(2)

ETRAFLI_BUTTON.click()

time.sleep(1)

actions.move_to_element(METRO_SELECT_BUTTON).click().pause(2) \
.move_to_element(NARIMANOV_SELECT_BUTTON).click().pause(2) \
.move_to_element(AXTARISA_ELAVE_ET_BUTTON).click().pause(1) \
.move_to_element(ELANI_GOSTER_BUTTON).click().perform()


NOVBETI_LOCATOR = ("xpath", "//span[@class='next']")
NOVBETI_BUTTON = driver.find_element(*NOVBETI_LOCATOR)

time.sleep(5)

actions.click(NOVBETI_BUTTON).perform()
